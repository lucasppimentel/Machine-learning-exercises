# %%
# Ambiente
import os

# Webscraper
from utils import extract_article_text, find_relevant_links

# Vector Database
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings

# AI
from langchain.chat_models import init_chat_model
from langchain.prompts import PromptTemplate

# Monitoramento
from langfuse.langchain import CallbackHandler

# Pipeline de Dados e Parsing
from sqlalchemy import create_engine
import datetime as dt
import pandas as pd
import re
import unicodedata

# %%
# LangChain setup
summarizer = init_chat_model("gpt-4o-mini", model_provider="openai")

template = PromptTemplate(
    input_variables=["text", "source"],
    template=(
        "Resuma a notícia a seguir de forma sucinta:\n\n"
        "{text}\n\n"
        "Resumo:"
    )
)

# CallbackHandler do LangFuse (parâmetros no Env)
langfuse_handler = CallbackHandler()

# Instância da IA
llm = init_chat_model("gpt-4o-mini", model_provider="openai")

# %%
# Sites do webscraper
news_sites = [
    "https://valor.globo.com/",
    "https://www.folha.uol.com.br/",
    "https://exame.com/",
    "https://oglobo.globo.com/"
]

# %%
# Carregando a vector database com o documento de ITR
path_chroma = "./02. Databases/chroma_db"

embeddings = OpenAIEmbeddings()
vectorstore = Chroma(persist_directory=path_chroma, embedding_function=embeddings, collection_name="PetrobrasV2")

# %% [markdown]
# # 01. Extract
#
# - Implementação do WebScraper das notícias
# - Resumo simples feito pela IA

# %%
# Lista de resumos
summaries = list()

for site in news_sites:
    print(f"\n🔍 Procurando notícias em: {site}")
    links = find_relevant_links(site)

    for link in links:
        print(f"📰 Lendo: {link}", end=" ...")
        article, title = extract_article_text(link)

        if article and len(article.split()) > 100:
            print("Criando Resumo")
            summary = summarizer.invoke(template.invoke({"text": article[:10000], "source": link}), config={"callbacks": [langfuse_handler]}).content
            summaries.append((link, summary, title))
        else: print()

print("\n📊 RESUMOS RELEVANTES PARA O MERCADO:\n")
for i, (link, summary, title) in enumerate(summaries, 1):
    print(f"{i}. {link}\n{summary}\n{'-'*80}")

# Armazenar output em Data Frame
df_summaries = pd.DataFrame(data=summaries, columns=["url", "summary", "Titulo"])
# Out:
# 🔍 Procurando notícias em: https://valor.globo.com/
# 📰 Lendo: https://valor.globo.com/financas/mercados/ ...Criando Resumo
# 📰 Lendo: https://valor.globo.com/publicacoes/especiais/tecnologia-bancaria/noticia/2025/06/18/bancos-investem-na-corrida-da-hiperpersonalizacao.ghtml ...Criando Resumo
# 📰 Lendo: https://valor.globo.com/financas/noticia/2025/06/22/para-onde-a-guerra-do-ir-vai-3-possveis-cenrios-para-o-petrleo-e-as-bolsas.ghtml ...Criando Resumo
# 📰 Lendo: https://valor.globo.com/publicacoes/especiais/tecnologia-bancaria/noticia/2025/06/18/tecnologia-e-customizacao-transformam-relacoes-dos-bancos-com-os-clientes.ghtml ...Criando Resumo
# 📰 Lendo: https://valor.globo.com/legislacao/noticia/2025/06/20/ministros-do-stf-suspendem-decisoes-do-tst.ghtml ...Criando Resumo
#
# 🔍 Procurando notícias em: https://www.folha.uol.com.br/
# 📰 Lendo: https://www1.folha.uol.com.br/mercado/mercado-imobiliario/ ...Criando Resumo
# 📰 Lendo: https://www1.folha.uol.com.br/opiniao/2025/06/a-tragedia-do-mercado-de-opinioes.shtml ...Criando Resumo
# 📰 Lendo: https://aovivo.folha.uol.com.br/mercado/2025/06/01/6418-dolar-empresas-e-bolsas-acompanhe-ao-vivo-o-mercado.shtml ...
#
# 🔍 Procurando notícias em: https://exame.com/
# 📰 Lendo: https://exame.com/brasil/governo-lula-condena-ataques-dos-eua-a-instalacoes-nucleares-do-ira/ ...Criando Resumo
# 📰 Lendo: https://exame.com/economia/fraude-no-inss-governo-vai-reembolsar-aposentados-e-pensionistas-em-parcela-unica/ ...Criando Resumo
# 📰 Lendo: https://exame.com/mercado-imobiliario/ ...Criando Resumo
#
# 🔍 Procurando notícias em: https://oglobo.globo.com/
# 📰 Lendo: https://oglobo.globo.com/mundo/noticia/2025/06/22/martelo-da-meia-noite-saiba-como-os-eua-usaram-isca-no-pacifico-para-despistar-ataque-a-instalacoes-nucleares-do-ira.ghtml ...Criando Resumo
# 📰 Lendo: https://oglobo.globo.com/mundo/noticia/2025/06/22/imagens-de-satelite-mostram-em-detalhes-os-danos-nas-instalacoes-nucleares-iranianas-atacadas-por-israel-e-pelos-eua.ghtml ...Criando Resumo
# 📰 Lendo: https://oglobo.globo.com/cultura/noticia/2025/06/22/apos-perder-casa-nos-incendios-da-california-paris-hilton-compra-mansao-de-r-347-milhoes-de-mark-wahlberg.ghtml ...Criando Resumo
#
# 📊 RESUMOS RELEVANTES PARA O MERCADO:
#
# 1. https://valor.globo.com/financas/mercados/
# A alta liderança empresarial se beneficiaria da prática esportiva, sendo uma atividade que envolve diversos adeptos. Em meio a tensões geopolíticas entre Irã e Israel e um mercado financeiro instável, o dólar se mantém valorizado devido ao diferencial de juros entre Brasil e EUA. O colegiado apoia melhorias na governança corporativa com ampla participação do mercado. A expectativa é de um possível corte de 0,25 ponto percentual na taxa de juros, com o Copom prestes a divulgar sua decisão. No acumulado de junho, o fluxo cambial é positivo em US$ 345 milhões.
# --------------------------------------------------------------------------------
# 2. https://valor.globo.com/publicacoes/especiais/tecnologia-bancaria/noticia/2025/06/18/bancos-investem-na-corrida-da-hiperpersonalizacao.ghtml
# A era da hiperpersonalização no setor bancário está se intensificando, com o uso crescente de inteligência artificial e IA generativa (GenIA) para atender às necessidades individuais dos clientes. Em 2024, 75% das transações bancárias foram realizadas por meio de dispositivos móveis, evidenciando a digitalização dos serviços financeiros. O Banco Central do Brasil, sob a liderança de Gabriel Galípolo, está promovendo inovações como o Pix 2.0, que inclui modalidades automáticas e parceladas, visando incluir milhões sem acesso a cartão de crédito. Bancos tradicionais, como Banco do Brasil, Bradesco e Itaú, estão investindo em tecnologia e formação de funcionários para se tornarem mais competitivos em um ambiente digital, buscando oferecer soluções personalizadas e transformando seu modelo de operação de transacional para consultivo.
# --------------------------------------------------------------------------------
# 3. https://valor.globo.com/financas/noticia/2025/06/22/para-onde-a-guerra-do-ir-vai-3-possveis-cenrios-para-o-petrleo-e-as-bolsas.ghtml
# Após a decisão dos EUA de se unir à guerra de Israel contra o Irã, surgem três possíveis caminhos: o Irã pode admitir a derrota, o que aliviará a pressão sobre os preços do petróleo e favoreceria os mercados. António Guterres recomenda o retorno de inspetores nucleares ao Irã e a retomada das negociações. Enquanto isso, um cessar-fogo proposto por China, Rússia e Paquistão poderia afetar as exportações de gás natural liquefeito (GNL), das quais o Brasil depende para abastecimento. O Ministério das Relações Exteriores do Brasil clama por uma solução diplomática. Em meio à incerteza sobre os ataques do Irã, analistas discutem a importância de diferenciar entre ameaças e ações concretas.
# --------------------------------------------------------------------------------
# 4. https://valor.globo.com/publicacoes/especiais/tecnologia-bancaria/noticia/2025/06/18/tecnologia-e-customizacao-transformam-relacoes-dos-bancos-com-os-clientes.ghtml
# A experiência do cliente se tornou crucial para os bancos, destacando-se na pesquisa da Febraban como prioridade na diferenciação. O presidente do Bradesco, Marcelo Noronha, enfatizou o papel da inteligência artificial (IA) e da IA generativa na personalização dos serviços, com a assistente Bia atendendo 24 milhões de correntistas. O Santander investe em tecnologia para melhorar a relação com os clientes, incluindo o microcrédito Prospera. A Caixa se concentra na segurança digital e está adotando um novo modelo de financiamento imobiliário. O BTG Pactual, focado em varejo de alta renda, também viu ganhos significativos com a digitalização e IA, ressaltando a importância da análise de dados para crescimento futuro.
# --------------------------------------------------------------------------------
# 5. https://valor.globo.com/legislacao/noticia/2025/06/20/ministros-do-stf-suspendem-decisoes-do-tst.ghtml
# O Supremo Tribunal Federal (STF) suspendeu, em duas decisões, acórdãos do Tribunal Superior do Trabalho (TST) que haviam mantido condenações superiores aos pedidos nas ações judiciais, beneficiando o Itaú Unibanco. As liminares foram concedidas pelos ministros Gilmar Mendes e Alexandre de Moraes.
# --------------------------------------------------------------------------------
# 6. https://www1.folha.uol.com.br/mercado/mercado-imobiliario/
# A Caixa Econômica Federal está aguardando um estudo para reestruturar o financiamento habitacional. Houve um aumento nas contratações do programa Minha Casa Minha Vida para famílias com renda de até R$ 12 mil, superando o crédito tradicional pela primeira vez. O setor imobiliário está se expandindo, impulsionado por iniciativas para aumentar a transparência e eficiência, além de um maior interesse por imóveis de maior padrão. No entanto, há preocupações com o aumento dos preços devido a fatores como a alta no custo da mão de obra e a pressão sobre o mercado, que pode desacelerar os investimentos. Além disso, uma pesquisa indica que 24% dos brasileiros planejam comprar um imóvel neste ano.
# --------------------------------------------------------------------------------
# 7. https://www1.folha.uol.com.br/opiniao/2025/06/a-tragedia-do-mercado-de-opinioes.shtml
# A notícia discute a teoria da "tragédia dos comuns", que expõe como a exploração excessiva de recursos comuns por indivíduos levando à sua degradação pode ser aplicada a vários contextos, incluindo a crise ambiental e o debate político. O autor alerta para o mercado de opiniões, onde a falta de responsabilidade e a disseminação desenfreada de opiniões não fundamentadas podem levar à descredibilização da expressão pessoal. Ele enfatiza que, embora a opinião não seja um recurso escasso, a qualidade e a confiança nela estão em risco, resultando na "extinção" da verdadeira opinião e na predominância de informações superficiais ou enganosas.
# --------------------------------------------------------------------------------
# 8. https://exame.com/brasil/governo-lula-condena-ataques-dos-eua-a-instalacoes-nucleares-do-ira/
# O governo brasileiro, sob a liderança do presidente Luiz Inácio Lula da Silva, condenou veementemente os ataques dos Estados Unidos a três instalações nucleares do Irã, expressando grave preocupação com a escalada militar no Oriente Médio. O Itamaraty afirmou que tais ações violam a soberania do Irã e o direito internacional, representando uma ameaça à saúde das populações civis e ao meio ambiente. O Brasil reiterou sua posição a favor do uso pacífico da energia nuclear e defendeu a busca por soluções diplomáticas para evitar a violência. Após os ataques, os EUA alegaram que a ação foi limitada e sem intenção de derrubar o regime iraniano, enquanto o Irã prometeu responder, afirmando que os EUA ultrapassaram uma "linha vermelha".
# --------------------------------------------------------------------------------
# 9. https://exame.com/economia/fraude-no-inss-governo-vai-reembolsar-aposentados-e-pensionistas-em-parcela-unica/
# O Governo Federal anunciou que o ressarcimento aos aposentados e pensionistas vítimas de descontos indevidos será feito em uma única parcela, sem priorização, ainda este ano. Até agora, 3,2 milhões de pessoas se manifestaram sobre os descontos não autorizados. O processo de pagamento ocorrerá a cada 15 dias, com medidas para garantir que todos os afetados sejam identificados. O Supremo Tribunal Federal agendou uma audiência para discutir o ressarcimento e suspendeu o prazo de prescrição para eventuais reivindicações judiciais.
# --------------------------------------------------------------------------------
# 10. https://exame.com/mercado-imobiliario/
# O texto destaca a seção de perguntas e respostas com especialistas, onde leitores podem enviar suas dúvidas e obter respostas. A publicação inclui uma série de artigos recentes sobre diversos tópicos, incluindo o mercado imobiliário, que foram publicados ao longo dos últimos dias.
# --------------------------------------------------------------------------------
# 11. https://oglobo.globo.com/mundo/noticia/2025/06/22/martelo-da-meia-noite-saiba-como-os-eua-usaram-isca-no-pacifico-para-despistar-ataque-a-instalacoes-nucleares-do-ira.ghtml
# Na madrugada de 22 de junho de 2025, os EUA lançaram a operação "Martelo da Meia-Noite", um ataque surpresa às instalações nucleares do Irã, utilizando bombardeiros B-2 Spirit e mísseis de cruzeiro Tomahawk. Enquanto um grupo de bombardeiros se dirigiu ao Pacífico para despistar a inteligência, outro grupo atacou alvos no Irã, incluindo as instalações em Fordow, Natanz e Isfahan, usando técnicas de desorientação. O ataque envolveu 125 aeronaves e 75 armas guiadas, incluindo bombas fura-bunker. Segundo o Pentágono, todos os alvos foram atingidos, mas a extensão dos danos ainda não é conhecida. O Irã respondeu, afirmando que os EUA cruzaram uma "grande linha vermelha" e prometendo defesa contundente.
# --------------------------------------------------------------------------------
# 12. https://oglobo.globo.com/mundo/noticia/2025/06/22/imagens-de-satelite-mostram-em-detalhes-os-danos-nas-instalacoes-nucleares-iranianas-atacadas-por-israel-e-pelos-eua.ghtml
# Os Estados Unidos atacaram três instalações nucleares no Irã — Natanz, Isfahan e Fordo — durante a madrugada de sábado (21), formalizando sua entrada na guerra entre Israel e Irã, que começou na semana passada. O Pentágono afirmou que as instalações sofreram "danos severos". Imagens de satélite mostram estragos nos locais. O ataque ocorreu após forças israelenses atingirem anteriormente os mesmos alvos. A escalada do conflito gerou condenações internacionais, e autoridades da ONU pedem o retorno de inspetores nucleares ao Irã.
# --------------------------------------------------------------------------------
# 13. https://oglobo.globo.com/cultura/noticia/2025/06/22/apos-perder-casa-nos-incendios-da-california-paris-hilton-compra-mansao-de-r-347-milhoes-de-mark-wahlberg.ghtml
# Após perder sua casa em Malibu nos incêndios da Califórnia, Paris Hilton comprou uma nova mansão em Beverly Hills por R$ 347 milhões. A propriedade, anterior de Mark Wahlberg, possui 2.800 m² e inclui 12 quartos, sala de jogos, e campo de golfe. Hilton compartilhou sua tristeza nas redes sociais ao ver sua antiga casa queimar, onde construiu muitas memórias com sua família.
# --------------------------------------------------------------------------------

# %% [markdown]
# # 02. Transform
#
# - Classificação de impacto e relevância com RAG

# %% [markdown]
# ### RAG e Pós-RAG
#
# 1. Primeira extração de Chunks do documento da Petrobrás
# 2. Remoção de ruído e filtro de chunks relevantes com LLM

# %%
query = """
<Instrução>
Você esta ajudando a analisar se o resumo da notícia é relevante para a estratégia da empresa ou não
<Instrução>

<Resumo da Notícia>
{summary}
<Resumo da Notícia>

Abaixo são chunks de documentos internos da empresa.

<Chunks>
{chunks}
<Chunks>

Reordene os chunks do mais útil ao menos útil para determinar a relevância para a estratégia da empresa. Responda somente com os mais úteis.
"""

pos_rag_template = PromptTemplate(
    input_variables=["summary", "chunks"],
    template=query
)

def CleanRetrievals(resumo, chunks_):
    docs = "\n\n".join([x.page_content for i, x in enumerate(chunks_)])

    response = llm.invoke(
        pos_rag_template.invoke({"summary":resumo, "chunks":docs}), 
        config={"callbacks": [langfuse_handler]}
    ).content

    return response

# %% [markdown]
# ### Classificação das notícias com LLM
#
# Chain-of-Thought + RAG

# %%
query = """
<Instrução>
Você é um especialista financeiro especializado na Petrobrás. Leia o resumo da notícia e, com base no contexto fornecido, avalie se ela é relevante ou não para a Petrobrás. Apresente seu raciocínio passo a passo com base em elementos do contexto e da notícia. Em seguida, forneça os seguintes critérios:
Relevância: ["Relevante" ou "Não Relevante"]
Impacto: ["Positivo", "Negativo" ou "Neutro"]
Nível: ["Alto", "Médio" ou "Baixo"]
Key-Takeaways: [Pontos chave do seu raciocínio]
<Instrução>

<Variáveis>
Contexto: Contém trechos do Formulário de Referência da Petrobrás, que contém informações sobre riscos e sobre a estratégia da empresa.
Notícia: Resumo de uma notícia.
<Variáveis>

<Contexto>
{context}
<Contexto>

<Formato da Resposta>
**Análise e Raciocínio**: [Explique passo a passo como a notícia se conecta (ou não) com o contexto da Petrobrás, mencionando possíveis impactos financeiros, estratégicos, regulatórios ou reputacionais.]

Relevância: "Relevante" ou "Não Relevante"
Impacto: "Positivo", "Negativo" ou "Neutro"
Nível: "Alto", "Médio" ou "Baixo"
Key-Takeaways: 
- Primeiro takeaway do seu racicínio, em poucas palavras. Adicione um ou mais, se for relevante.
- Segundo takeaway do seu racicínio, em poucas palavras. Se for relevante
- Tericeiro takeaway do seu racicínio, em poucas palavras. Se for relevante
<Formato da Resposta>

<Notícia>
{summary}
<Notícia>
"""

prompt_template = PromptTemplate(
    input_variables=["context", "summary"],
    template=query
)

# %%
for i, summary in df_summaries.iterrows():
    print(f"{i+1} / {len(df_summaries)}", end=" ...")

    # Retrieval + Pós-Retrieval
    docs = vectorstore.similarity_search(summary["summary"], k=20)
    filtered = [doc for doc in docs if doc.metadata.get("category") in ["Empresa e estrutura", "Operações e mercado", "Riscos e conformidade", "ESG e sustentabilidade"]]
    context = CleanRetrievals(summary["summary"], filtered)

    # Classificação da notícia
    response = llm.invoke(
        prompt_template.invoke({"summary":summary["summary"], "context":context}), 
        config={"callbacks": [langfuse_handler]}
    ).content

    # Output Parsing
    for variavel in ["Relevância", "Impacto", "Nível"]:
        parsed = re.findall(fr'{variavel}:\s*\"([^\n]+)\"', response.replace("*", ""))[0]

        nfkd_form = unicodedata.normalize('NFKD', variavel).lower()
        col = "".join([c for c in nfkd_form if not unicodedata.combining(c)])
        df_summaries.loc[i, col] = parsed

    takeaways = response.split("Key-Takeaways:")[-1]
    df_summaries.loc[i, "Takeaways"] = takeaways
    df_summaries.loc[i, "Pensamento"] = response
    
    print(f"{df_summaries.loc[i, "nivel"]} {df_summaries.loc[i, "impacto"]}" if df_summaries.loc[i, "relevancia"] == "Relevante" else df_summaries.loc[i, "relevancia"])
# Out:
# 1 / 13 ...Médio Positivo
# 2 / 13 ...Médio Neutro
# 3 / 13 ...Alto Negativo
# 4 / 13 ...Não Relevante
# 5 / 13 ...Não Relevante
# 6 / 13 ...Não Relevante
# 7 / 13 ...Não Relevante
# 8 / 13 ...Alto Negativo
# 9 / 13 ...Não Relevante
# 10 / 13 ...Não Relevante
# 11 / 13 ...Alto Positivo
# 12 / 13 ...Alto Negativo
# 13 / 13 ...Não Relevante

# %% [markdown]
# # 03. Load

# %%
path_summaries_database = "./02. Databases/Summaries/"
hoje = dt.datetime.now().strftime(format="%Y-%m-%d")

df_summaries["Date"] = hoje

if not os.path.exists(path_summaries_database):
    os.makedirs(path_summaries_database)
df_summaries.to_csv(path_summaries_database + f"{hoje}.csv")

# %%
df_summaries.columns = list(map(lambda x: x.lower(), df_summaries.columns))
df_summaries = df_summaries.rename(columns={"titulo": "title", "pensamento": "ideia", "nivel": "relevancia", "relevancia": "flag", "flag": "relevancia"})

db_url = f'postgresql+psycopg2://{os.environ["POSTGRES_USER"]}:{os.environ["POSTGRES_PASSWORD"]}@localhost:5432/{os.environ["POSTGRES_DATABASE"]}'

# Create SQLAlchemy engine
engine = create_engine(db_url)

# Append data to the existing table
df_summaries.to_sql(name="summaries", schema="ai", con=engine, if_exists='append', index=False)
# Out:
# 13

# %%
db_url
# Out:
# 'postgresql+psycopg2://postgres:@localhost:5432/postgres'

# %%
df_summaries.columns = ['url', 'summary', 'title', 'flag', 'impacto', 'relevancia', 'takeaways', 'ideia', 'date']

# %%
df_summaries
# Out:
#                                                   url  \
# 0          https://valor.globo.com/financas/mercados/
# 1   https://valor.globo.com/publicacoes/especiais/...
# 2   https://valor.globo.com/financas/noticia/2025/...
# 3   https://valor.globo.com/publicacoes/especiais/...
# 4   https://valor.globo.com/legislacao/noticia/202...
# 5   https://www1.folha.uol.com.br/mercado/mercado-...
# 6   https://www1.folha.uol.com.br/opiniao/2025/06/...
# 7   https://exame.com/brasil/governo-lula-condena-...
# 8   https://exame.com/economia/fraude-no-inss-gove...
# 9              https://exame.com/mercado-imobiliario/
# 10  https://oglobo.globo.com/mundo/noticia/2025/06...
# 11  https://oglobo.globo.com/mundo/noticia/2025/06...
# 12  https://oglobo.globo.com/cultura/noticia/2025/...
#
#                                               summary  \
# 0   A alta liderança empresarial se beneficiaria d...
# 1   A era da hiperpersonalização no setor bancário...
# 2   Após a decisão dos EUA de se unir à guerra de ...
# 3   A experiência do cliente se tornou crucial par...
# 4   O Supremo Tribunal Federal (STF) suspendeu, em...
# 5   A Caixa Econômica Federal está aguardando um e...
# 6   A notícia discute a teoria da "tragédia dos co...
# 7   O governo brasileiro, sob a liderança do presi...
# 8   O Governo Federal anunciou que o ressarcimento...
# 9   O texto destaca a seção de perguntas e respost...
# 10  Na madrugada de 22 de junho de 2025, os EUA la...
# 11  Os Estados Unidos atacaram três instalações nu...
# 12  Após perder sua casa em Malibu nos incêndios d...
#
#                                                 title     relevancia  \
# 0                                            Mercados      Relevante
# 1   Bancos investem na corrida da hiperpersonaliza...      Relevante
# 2   Para onde a Guerra do Irã vai: 3 possíveis cen...      Relevante
# 3   Tecnologia e customização transformam relações...  Não Relevante
# 4   Ministros do STF suspendem decisões do TST | L...  Não Relevante
# 5   Mercado ImobiliÃ¡rio: notÃ­cias sobre compra e...  Não Relevante
# 6   A tragÃ©dia do mercado de opiniÃµes - 21/06/20...  Não Relevante
# 7   Governo Lula condena ataques dos EUA a instala...      Relevante
# 8   Fraude no INSS: governo vai reembolsar aposent...  Não Relevante
# 9   Mercado Imobiliário | Notícias sobre compra, v...  Não Relevante
# 10  ‘Martelo da Meia-Noite’: Saiba como os EUA usa...      Relevante
# 11  Imagens de satélite mostram em detalhes os dan...      Relevante
# 12  Após perder casa nos incêndios da Califórnia, ...  Não Relevante
#
#      impacto   flag                                          takeaways  \
# 0   Positivo  Médio   \n- Governança corporativa é um foco relevant...
# 1     Neutro  Médio   \n- Aumento na utilização de IA pode influenc...
# 2   Negativo   Alto  \n- A complexidade da situação geopolítica no ...
# 3     Neutro  Baixo   \n- A digitalização é relevante no setor fina...
# 4     Neutro  Baixo   \n- A decisão do STF não impacta diretamente ...
# 5     Neutro  Baixo    \n- A notícia não impacta diretamente a Petr...
# 6     Neutro  Baixo    \n- A relação indireta entre exploração de r...
# 7   Negativo   Alto   \n- Tensões no Oriente Médio impactam a volat...
# 8     Neutro  Baixo   \n- A notícia é voltada a questões sociais e ...
# 9     Neutro  Baixo   \n- A notícia não aborda diretamente questões...
# 10  Positivo   Alto    \n- A escalada das tensões no Oriente Médio ...
# 11  Negativo   Alto   \n- Crescente risco geopolítico afeta o preço...
# 12    Neutro  Baixo   \n- A compra de um imóvel por Paris Hilton nã...
#
#                                                 ideia        date
# 0   **Análise e Raciocínio**: A notícia menciona v...  2025-06-22
# 1   **Análise e Raciocínio**: \n\n1. **Conexão com...  2025-06-22
# 2   **Análise e Raciocínio**: A notícia é altament...  2025-06-22
# 3   **Análise e Raciocínio**:  \nA notícia se conc...  2025-06-22
# 4   **Análise e Raciocínio**: A notícia se refere ...  2025-06-22
# 5   **Análise e Raciocínio**: A notícia sobre a Ca...  2025-06-22
# 6   **Análise e Raciocínio**: A notícia sobre a te...  2025-06-22
# 7   **Análise e Raciocínio**: A notícia sobre os a...  2025-06-22
# 8   **Análise e Raciocínio**: A notícia sobre o re...  2025-06-22
# 9   **Análise e Raciocínio**: A notícia mencionada...  2025-06-22
# 10  **Análise e Raciocínio**: A notícia sobre a op...  2025-06-22
# 11  **Análise e Raciocínio**: A notícia sobre o at...  2025-06-22
# 12  **Análise e Raciocínio**: A notícia sobre Pari...  2025-06-22
